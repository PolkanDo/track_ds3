# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
export_2017 = pd.read_excel('russia_2017.xlsx', sheet_name='Partner')
export_2018 = pd.read_excel('russia_2018.xlsx', sheet_name='Partner')

# %%
export_2017.head()
# Out:
#         Reporter Name Partner Name  Year Trade Flow  \
# 0  Russian Federation        Aruba  2017     Export
# 1  Russian Federation  Afghanistan  2017     Export
# 2  Russian Federation       Angola  2017     Export
# 3  Russian Federation      Anguila  2017     Export
# 4  Russian Federation      Albania  2017     Export
#
#    No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 0                                2.0                                0.05
# 1                              221.0                                5.06
# 2                              530.0                               12.14
# 3                                NaN                                 NaN
# 4                               69.0                                1.58
#
#    Export (US$ Thousand)  Export Partner Share (%)
# 0                3535.44                      0.00
# 1              258932.36                      0.07
# 2              128680.03                      0.03
# ...

# %%
export_2018.head()
# Out:
#         Reporter Name Partner Name  Year Trade Flow  \
# 0  Russian Federation        Aruba  2018     Export
# 1  Russian Federation  Afghanistan  2018     Export
# 2  Russian Federation       Angola  2018     Export
# 3  Russian Federation      Anguila  2018     Export
# 4  Russian Federation      Albania  2018     Export
#
#    No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 0                                2.0                                0.05
# 1                              243.0                                5.57
# 2                              244.0                                5.59
# 3                                NaN                                 NaN
# 4                              130.0                                2.98
#
#    Export (US$ Thousand)  Export Partner Share (%)
# 0                  31.47                      0.00
# 1              118660.67                      0.03
# 2               49469.28                      0.01
# ...

# %%
export = pd.concat([export_2017, export_2018])

# %%
export.sample(10)
# Out:
#           Reporter Name         Partner Name  Year Trade Flow  \
# 81   Russian Federation        Guinea-Bissau  2018     Export
# 36   Russian Federation          Switzerland  2018     Export
# 151  Russian Federation               Norway  2017     Export
# 11   Russian Federation  Antigua and Barbuda  2017     Export
# 209  Russian Federation               Tuvalu  2018     Export
# 147  Russian Federation              Nigeria  2017     Export
# 98   Russian Federation              Ireland  2018     Export
# 78   Russian Federation            Gibraltar  2018     Export
# 13   Russian Federation           Azerbaijan  2018     Export
# 105  Russian Federation                Kenya  2017     Export
#
#      No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 81                                 NaN                                 NaN
# 36                               715.0                               16.38
# ...

# %%
exclude = [' World', 'Europe & Central Asia', 'East Asia & Pacific', 'Middle East & North Africa', 'Unated Stats Minor Outlying I']
export_filters = export[-export['Partner Name'].isin(exclude)]

# %%
export_pivot = export_filters.pivot_table(index=['Year', 'Partner Name'], values='Export (US$ Thousand)', aggfunc='sum')\
    .sort_values(['Year','Export (US$ Thousand)'], ascending=[True, False])

# %%
export_pivot[export_pivot.index.get_level_values('Year') == 2017]
# Out:
#                                      Export (US$ Thousand)
# Year Partner Name
# 2017 China                                     41671349.42
#      Netherlands                               38234057.85
#      Germany                                   26202990.31
#      Belarus                                   20335904.87
#      Turkey                                    19044758.56
# ...                                                    ...
#      Swaziland                                        0.00
#      Tokelau                                          0.00
#      Turks and Caicos Isl.                            0.00
#      Tuvalu                                           0.00
#      United States Minor Outlying I                   0.00
#
# [226 rows x 1 columns]
